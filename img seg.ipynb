# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
model = YOLO("C:/Users/ahmed/Downloads/YOLO Segmentation/yolov8n-seg.pt")
results = model("C:/Users/ahmed/Downloads/YOLO Segmentation")
# Out:
# image 1/1 C:\Users\ahmed\Downloads\YOLO Segmentation\img.jpg: 416x640 30 persons, 11 cars, 245.7ms
# Speed: 15.8ms preprocess, 245.7ms inference, 67.0ms postprocess per image at shape (1, 3, 416, 640)

# %%
result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
