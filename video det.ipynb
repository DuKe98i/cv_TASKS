# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO("C:/Users/ahmed/Downloads/YOLO Detection/yolov8n.pt")
results = model(source="C:/Users/ahmed/Downloads/YOLO Detection", stream=True, show=True, conf=0.4, save=True)
for result in results:
    frame = result.plot()
    cv2.imshow("processed frame",frame)
# Out:
# video 1/1 (frame 1/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 2 persons, 2 cars, 1 truck, 87.6ms
# video 1/1 (frame 2/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 2 persons, 4 cars, 1 truck, 83.7ms
# video 1/1 (frame 3/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 2 persons, 5 cars, 1 truck, 74.1ms
# video 1/1 (frame 4/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 3 persons, 3 cars, 1 truck, 70.7ms
# video 1/1 (frame 5/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 3 persons, 3 cars, 1 truck, 68.6ms
# video 1/1 (frame 6/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 3 persons, 3 cars, 1 truck, 74.0ms
# video 1/1 (frame 7/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 2 persons, 3 cars, 1 truck, 73.0ms
# video 1/1 (frame 8/288) C:\Users\ahmed\Downloads\YOLO Detection\BMW.mp4: 640x384 3 persons, 3 cars, 1 truck, 69.6ms
# ...
